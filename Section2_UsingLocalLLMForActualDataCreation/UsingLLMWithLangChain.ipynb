# %% [markdown]
# ### Using Local LLM with LangChain

# %% [markdown]
# ### Creating Confident AI Model Login

# %%
import os
import deepeval
from dotenv import load_dotenv

load = load_dotenv('./../.env.local', override=True)
api_key = os.getenv("CONFIDENT_API_KEY")
print("CONFIDENT_API_KEY :", api_key)
if api_key is None:
    raise ValueError("CONFIDENT_API_KEY environment variable is not set")

deepeval.login(api_key)
# Out:
# CONFIDENT_API_KEY : confident_us_mts7MhmRWuwEq3iOrRXqmLYe1uj6/XF+vE8ICt6568U=
# 🎉🥳 Congratulations! You've successfully logged in! 🙌

# %%
import os
from dotenv import load_dotenv
# load_model_key = load_dotenv('./../Section1_Introduction/.env_gemini', override=True)
load_deepeval_key = load_dotenv('./../.env.local', override=True)
#load = load_dotenv('./../.env')
# print("Load dotenv:", load)
print("OPENAI_API_KEY :", os.getenv("OPENAI_API_KEY"))
print("CONFIDENT_API_KEY :", os.getenv("CONFIDENT_API_KEY"))
print("OLLAMA_API_KEY :", os.getenv("OLLAMA_API_KEY"))
# Out:
# OPENAI_API_KEY : AIzaSyD5m49-V4lA0Pm6RxeEOW-YmChgwW6zcuM
# CONFIDENT_API_KEY : confident_us_mts7MhmRWuwEq3iOrRXqmLYe1uj6/XF+vE8ICt6568U=
# OLLAMA_API_KEY : YOUR_SECRET

# %%
# !pip install langchain
# !pip install langchain-ollama
# !pip insgtall langchain-community

# %%
# !deepeval set-ollama llama3:latest
# Out:
# Settings updated for this session. To persist, use --save=dotenv[:path]
# (default .env.local) or set DEEPEVAL_DEFAULT_SAVE=dotenv:.env.local
# 🙌 Congratulations! You're now using a local Ollama model `llama3:latest` for
# all evals that require an LLM.

# %%
# # from langchain_ollama import ChatOllama
# from deepeval.test_case import LLMTestCase
# from deepeval.evaluate import evaluate
# from deepeval.metrics import AnswerRelevancyMetric
# import os

# # ollama_api_key = os.getenv("OLLAMA_API_KEY")
# # print("Loaded Ollama API Key:", ollama_api_key)  # DEBUG

# # model = ChatOllama(
# #     base_url="http://localhost:11434",
# #     model="qwen:1.8b",
# #     temperature=0.5,
# # )
# metric = AnswerRelevancyMetric()
# # answer_relevancy_metric = AnswerRelevancyMetric()
# test_case = LLMTestCase(
#   input="Who is the current president of the United States of America?",
#   actual_output=llm.invoke("Who is the current president of the United States of America?").content,
#   retrieval_context=["Donald Trump serves as the current president of America."]
# )

# # evaluate(test_cases=[test_case], metrics=[answer_relevancy_metric])
# evaluate(test_cases=[test_case], metrics=[metric])


from langchain_ollama import ChatOllama


llm = ChatOllama(
    base_url="http://localhost:11434/",
    model="llama3:latest",
    temperature=0.5,
)

# %%
response = llm.invoke("Who is the current president of the United States of America? just give me the name no explainations needed")

# %%
print(response.content)
# Out:
# Joe Biden

# %% [markdown]
# #### Testing with Local LLMs as actual_output source and Evaluator

# %%
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate
import os

metric = AnswerRelevancyMetric()
# answer_relevancy_metric = AnswerRelevancyMetric()
response = llm.invoke("Who is the current president of the United States of America? just give me the name no explainations needed").content
print(response)
test_case = LLMTestCase(
  input="Who is the current president of the United States of America?",
  actual_output= "Joe Biden",
)

# evaluate(test_cases=[test_case], metrics=[answer_relevancy_metric])

evaluate(test_cases=[test_case], metrics=[metric])
# Out:
# Joe Biden
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using llama3:latest (Local Model), strict=False,
# async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[11], line 17
#      10 test_case = LLMTestCase(
#      11   input="Who is the current president of the United States of America?",
#      12   actual_output= "Joe Biden",
#      13 )
#      15 # evaluate(test_cases=[test_case], metrics=[answer_relevancy_metric])
# ---> 17 evaluate(test_cases=[test_case], metrics=[metric])
#
# ...

# %%
import os
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate
from deepeval.models import OllamaModel  # <-- THIS IS THE CORRECT IMPORT

# --- FIX: Configure the Evaluation Model ---

# 1. Create an instance of the model you want to use for *evaluation*
#    Make sure "llama3" (or your model of choice) is running on your Ollama server.
#    By default, it connects to "http://localhost:11434"
eval_model = OllamaModel(model="llama3:latest")

# If your server is on a different port:
# eval_model = OllamaModel(model="llama3", base_url="http://localhost:1234")

# 2. Pass the configured model to your metric
metric = AnswerRelevancyMetric(model=eval_model)

# -------------------------------------------

# Your original code
# (Assuming 'llm' is defined and works separately)
# response = llm.invoke("Who is the current president of the United States of America? just give me the name no explainations needed").content
response = "Joe Biden" # Simulating the response for this example
print(response)

test_case = LLMTestCase(
    input="Who is the current president of the United States of America?",
    actual_output= str(response),
)

# This will now use your local 'eval_model' (llama3) to perform the evaluation
evaluate(test_cases=[test_case], metrics=[metric])
# Out:
# Joe Biden
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using llama3:latest (Ollama), strict=False,
# async_mode=True)...
#     🎯 Evaluating test case #0 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:03:00
# ...
#
# Metrics Summary
#
#   - ❌ Answer Relevancy (score: None, threshold: 0.5, strict: False, evaluation model: llama3:latest (Ollama), reason: None, error: Timed out/cancelled while evaluating metric. Increase DEEPEVAL_PER_TASK_TIMEOUT_SECONDS_OVERRIDE or set DEEPEVAL_LOG_STACK_TRACES=1 for full traceback.)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: None
#   - context: None
#   - retrieval context: None
#
# ...
#
# Overall Metric Pass Rates
#
# Answer Relevancy: 0.00% pass rate
#
# ...
# ⚠ WARNING: No hyperparameters logged.
# ...

# %%
import os
from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate
from langchain_ollama import ChatOllama
from deepeval.models import OllamaModel

confident_api_key = os.getenv("CONFIDENT_API_KEY")
# print("Loaded Confident API Key:", confident_api_key)  # DEBUG

MODEL_NAME = "llama3:latest" 

llm = ChatOllama(model=MODEL_NAME)
eval_model = OllamaModel(model=MODEL_NAME)

# 3. Pass the evaluation model to your metric
metric = AnswerRelevancyMetric(model=eval_model)

# 4. Now, actually CALL your LangChain model to get the response
print(f"Asking Ollama ({MODEL_NAME})...")
question = "Who is the current president of the United States of America? just give me the name no explainations needed"
response = llm.invoke(question).content
print(f"Response: {response}")

# 5. Create the test case with the actual output from Ollama
test_case = LLMTestCase(
    input="Who is the current president of the United States of America?",
    actual_output=str(response),
)

# 6. Run the evaluation
print("Running DeepEval evaluation...")
evaluate(test_cases=[test_case], metrics=[metric])
# Out:
# Asking Ollama (llama3:latest)...
# Response: Joe Biden
# Running DeepEval evaluation...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using llama3:latest (Ollama), strict=False,
# async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
#
# Metrics Summary
#
#   - ✅ Answer Relevancy (score: 1.0, threshold: 0.5, strict: False, evaluation model: llama3:latest (Ollama), reason: The score is 1.00 because the actual output directly answers the question about the current president of the United States, making it highly relevant and leaving no room for improvement., error: None)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: None
#   - context: None
#   - retrieval context: None
#
# ...
#
# Overall Metric Pass Rates
#
# Answer Relevancy: 100.00% pass rate
#
# ...

# %%
import os
# --- THE FIX ---
# Increase the timeout to 5 minutes to give your local model time to "think"
os.environ["DEEPEVAL_PER_TASK_TIMEOUT_SECONDS_OVERRIDE"] = "300" 
# ---

from deepeval.test_case import LLMTestCase
from deepeval.metrics import AnswerRelevancyMetric
from deepeval.evaluate import evaluate

confident_api_key = os.getenv("CONFIDENT_API_KEY")
# print("Loaded Confident API Key:", confident_api_key)  # DEBUG

# --- PART 1: Imports for getting the answer from Ollama ---
from langchain_ollama import ChatOllama

# --- PART 2: Imports for evaluating the answer with Ollama ---
from deepeval.models import OllamaModel

# --- Configuration ---
MODEL_NAME = "llama3:latest" 

# 1. Define the LLM to GENERATE the answer (using LangChain)
llm = ChatOllama(model=MODEL_NAME)

# 2. Define the LLM to EVALUATE the answer (using DeepEval)
eval_model = OllamaModel(model=MODEL_NAME)

# 3. Pass the evaluation model to your metric
metric = AnswerRelevancyMetric(model=eval_model)

# 4. Now, actually CALL your LangChain model to get the response
print(f"Asking Ollama ({MODEL_NAME})...")
question = "Who is the current president of the United States of America? just give me the name no explainations needed"
response = llm.invoke(question).content
print(f"Response: {response}")

# 5. Create the test case with the actual output from Ollama
test_case = LLMTestCase(
    input="Who is the current president of the United States of America?",
    actual_output=str(response),
)

# 6. Run the evaluation
print("Running DeepEval evaluation...")
evaluate(test_cases=[test_case], metrics=[metric])
# Out:
# Loaded Confident API Key: confident_us_mts7MhmRWuwEq3iOrRXqmLYe1uj6/XF+vE8ICt6568U=
# Asking Ollama (llama3:latest)...
# Response: Joe Biden
# Running DeepEval evaluation...
# ✨ You're running DeepEval's latest Answer Relevancy Metric! (using llama3:latest (Ollama), strict=False,
# async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
#
# Metrics Summary
#
#   - ❌ Answer Relevancy (score: None, threshold: 0.5, strict: False, evaluation model: llama3:latest (Ollama), reason: None, error: Timed out/cancelled while evaluating metric. Increase DEEPEVAL_PER_TASK_TIMEOUT_SECONDS_OVERRIDE or set DEEPEVAL_LOG_STACK_TRACES=1 for full traceback.)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: None
#   - context: None
#   - retrieval context: None
#
# ...
#
# ...

# %% [markdown]
# #### ContextualPrecisionMetrics

# %%
import os
from deepeval.test_case import LLMTestCase
from deepeval.metrics import ContextualPrecisionMetric
from deepeval.evaluate import evaluate
from langchain_ollama import ChatOllama
from deepeval.models import OllamaModel

confident_api_key = os.getenv("CONFIDENT_API_KEY")
# print("Loaded Confident API Key:", confident_api_key)  # DEBUG

MODEL_NAME = "llama3:latest" 

llm = ChatOllama(model=MODEL_NAME)
eval_model = OllamaModel(model=MODEL_NAME)

# 3. Pass the evaluation model to your metric
metric = ContextualPrecisionMetric(model=eval_model, threshold=1.0)

# 4. Now, actually CALL your LangChain model to get the response
print(f"Asking Ollama ({MODEL_NAME})...")
question = "Who is the current president of the United States of America? just give me the name no explainations needed"
response = llm.invoke(question).content
print(f"Response: {response}")

# 5. Create the test case with the actual output from Ollama
test_case = LLMTestCase(
    input="Who is the current president of the United States of America?",
    actual_output=str(response),
    retrieval_context=["Joe Biden is the current president of the United States of America."],
    context= ["Joe Biden"],
    expected_output="Joe Biden"
)

# 6. Run the evaluation
print("Running DeepEval evaluation...")
evaluate(test_cases=[test_case], metrics=[metric])
# Out:
# Asking Ollama (llama3:latest)...
# Response: Joe Biden
# Running DeepEval evaluation...
# ✨ You're running DeepEval's latest Contextual Precision Metric! (using llama3:latest (Ollama), strict=False,
# async_mode=True)...
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ...
#
# Metrics Summary
#
#   - ❌ Contextual Precision (score: None, threshold: 1.0, strict: False, evaluation model: llama3:latest (Ollama), reason: None, error: Timed out/cancelled while evaluating metric. Increase DEEPEVAL_PER_TASK_TIMEOUT_SECONDS_OVERRIDE or set DEEPEVAL_LOG_STACK_TRACES=1 for full traceback.)
#
# For test case:
#
#   - input: Who is the current president of the United States of America?
#   - actual output: Joe Biden
#   - expected output: Joe Biden
#   - context: ['Joe Biden']
#   - retrieval context: ['Joe Biden is the current president of the United States of America.']
#
# ...
#
# ...
